# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/matplotlib-with-indonesia-belajar/blob/main/Matplotlib_06_Belajar_Pie_Plot_%7C_Pie_Chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib 06: Belajar Pie Plot | Pie Chart | Belajar Matplotlib Dasar | Belajar Visualisasi Data**

# %%
import matplotlib
import matplotlib.pyplot as plt

print(matplotlib.__version__)
# Out:
# 3.10.0

# %% [markdown]
# ### **Simple Pie Plot**

# %%
kategori = ['A', 'B', 'C', 'D', 'E']
data = [215, 130, 245, 210, 105]

# %%
plt.pie(data,
        labels=kategori,
        autopct='%1.1f%%',
        startangle=90)

plt.title('Contoh Pie Plot')
plt.show()

# %%
plt.pie(data,
        # labels=kategori,
        # autopct='%1.1f%%',
        startangle=90)

plt.title('Contoh Pie Plot')
plt.show()

# %% [markdown]
# ### **Pengaturan Legend dan Color**

# %%
kategori = ['A', 'B', 'C', 'D', 'E']
data = [215, 130, 245, 210, 105]
warna = ['pink', 'cyan', '#e03364', 'yellowgreen', 'skyblue']

# %%
plt.pie(data,
        labels=kategori,
        colors=warna,
        autopct='%1.1f%%',
        startangle=90)

plt.legend(kategori)
plt.title('Contoh Pie Plot')
plt.show()
