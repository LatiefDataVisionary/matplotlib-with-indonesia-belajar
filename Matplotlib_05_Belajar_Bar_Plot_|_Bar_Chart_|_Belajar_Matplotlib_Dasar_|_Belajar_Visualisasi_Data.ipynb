# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/matplotlib-with-indonesia-belajar/blob/main/Matplotlib_05_Belajar_Bar_Plot_%7C_Bar_Chart_%7C_Belajar_Matplotlib_Dasar_%7C_Belajar_Visualisasi_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib 05: Belajar Bar Plot | Bar Chart | Belajar Matplotlib Dasar | Belajar Visualisasi Data**

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.10.0
# 1.26.4

# %% [markdown]
# ### **Simple Bar Plot**

# %%
data = [25, 45, 55, 125, 225]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
plt.bar(kategori, data)
plt.grid()

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %% [markdown]
# ### **Pengaturan Grid dan Color**

# %%
data = [25, 45, 55, 125, 225]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
plt.bar(kategori,
        data,
        color = 'red',
        alpha=0.5)

plt.grid(linestyle='--',
         linewidth=2,
         axis='y', # pilihan: x, y, both
         alpha=0.50)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %%
plt.bar(kategori,
        data,
        color = 'red',
        alpha=0.5)

plt.grid(linestyle='--',
         linewidth=2,
         axis='both', # pilihan: x, y, both
         alpha=0.50)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Bar Plot')

plt.show()

# %% [markdown]
# ### **Horisontal Bar Plot**

# %%
data = [25, 45, 55, 125, 225]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
plt.barh(kategori, data)
# plt.barh(kategori[::-1], data[::-1])

plt.grid(linestyle='--',
         linewidth=1,
         axis='x',
         alpha=0.75)

plt.xlabel('Jumlah')
plt.ylabel('Kategori')
plt.title('Contoh Horizontal Bar Plot')

plt.show()

# %%
plt.barh(kategori[::-1], data[::-1])

plt.grid(linestyle='--',
         linewidth=1,
         axis='x',
         alpha=0.75)

plt.xlabel('Jumlah')
plt.ylabel('Kategori')
plt.title('Contoh Horizontal Bar Plot')

plt.show()

# %% [markdown]
# ### **Stacked Bar Plot**

# %%
data1 = [25, 85, 75, 40, az60]
data2 = [40, 35, 20, 55, 10]
kategori = ['A', 'B', 'C', 'D', 'E']

# %%
plt.bar(kategori, data1, label='Data 1', color='red')
# plt.bar(kategori, data2, label='Data 2')
plt.bar(kategori, data2, label='Data 2', color='b', bottom=data1, alpha=0.75)

plt.legend()

plt.grid(linestyle='--',
         linewidth=1,
         axis='y',
         alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %%
plt.bar(kategori, data1, label='Data 1', color='red', bottom=data2)
# plt.bar(kategori, data2, label='Data 2')
plt.bar(kategori, data2, label='Data 2', color='b', alpha=0.75)

plt.legend()

plt.grid(linestyle='--',
         linewidth=1,
         axis='y',
         alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %%
plt.bar(kategori, data1, label='Data 1')
plt.bar(kategori, data2, label='Data 2')

plt.legend()

plt.grid(linestyle='--',
         linewidth=1,
         axis='y',
         alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %%
plt.bar(kategori, data2, label='Data 2')
plt.bar(kategori, data1, label='Data 1')

plt.legend()

plt.grid(linestyle='--',
         linewidth=1,
         axis='y',
         alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %%
plt.bar(kategori, data2, label='Data X')
plt.bar(kategori, data1, label='Data Z', bottom=data1)

plt.legend()

plt.grid(linestyle='--',
         linewidth=1,
         axis='y',
         alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Stacked Bar Plot')

plt.show()

# %% [markdown]
# ### **Grouped Bar Plot**

# %%
data1 = [25, 85, 75, 40, 60]
data2 = [40, 35, 20, 55, 10]
kategori = ['A', 'B', 'C', 'D', 'E']

x = np.arange(len(kategori))
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
width = 0.35

plt.bar(x-width/2, data1, width, label='Data 1')
plt.bar(x+width/2, data2, width, label='Data 2')

plt.xticks(x, kategori)

plt.grid(linestyle='--',
         linewidth=1,
         axis='y',
         alpha=0.75)

plt.xlabel('Kategori')
plt.ylabel('Jumlah')
plt.title('Contoh Grouped Bar Plot')

plt.legend()
plt.show()
