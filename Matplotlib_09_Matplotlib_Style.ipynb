# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/matplotlib-with-indonesia-belajar/blob/main/Matplotlib_09_Matplotlib_Style.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib 09: Matplotlib Style | Belajar Matplotlib Dasar | Belajar Visualisasi Data**

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.10.0
# 1.26.4

# %% [markdown]
# Fungsi Plotting
