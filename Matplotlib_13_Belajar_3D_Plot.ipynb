# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/matplotlib-with-indonesia-belajar/blob/main/Matplotlib_13_Belajar_3D_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib 13: Belajar 3D Plot | 3D Chart | Belajar Matplotlib Dasar | Belajar Visualisasi Data**

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.10.0
# 1.26.4

# %% [markdown]
# ### **3D Axes**

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

plt.show()

# %% [markdown]
# ### **3D Line Plot**

# %%
z = np.linspace(0, 1, 100)
x = z * np.sin(20 * z)
y = z * np.cos(20 * z)

print('x:', x)
print('\ny:', y)
print('\nz:', z)
# Out:
# x: [ 0.          0.00202676  0.00794215  0.01726164  0.02921061  0.042772
#   0.05674926  0.06984124  0.08072494  0.08814145  0.09098035  0.08835778
#   0.07968367  0.06471401  0.04358511  0.01682728 -0.01464342 -0.04955535
#  -0.08633275 -0.12316609 -0.15809849 -0.18912393 -0.21429269 -0.23181857
#  -0.2401826  -0.23822759 -0.22523842 -0.20100348 -0.16585333 -0.12067393
#  -0.06689272 -0.00643723  0.05833275  0.12471708  0.18978782  0.25051755
#   0.30391803  0.34718275  0.37782696  0.39381819  0.3936909   0.37663923
#   0.34258276  0.29220129  0.22693586  0.14895487  0.06108567 -0.03328643
#  -0.13034818 -0.22601249 -0.31609029 -0.39647306 -0.46331802 -0.51322775
#  -0.54341599 -0.55185169 -0.53737434 -0.49977437 -0.43983418 -0.35932669
#  -0.26097026 -0.14834078 -0.02574347  0.10195101  0.22949993  0.35150376
#   0.46263436  0.55786659  0.63270326  0.68338338  0.70706433  0.70196925
#   0.6674924   0.60425687  0.51412092  0.40013144  0.26642521  0.11808096
# ...

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot(x, y, z, color='r')

ax.set(title='Contoh 3D Line Plot',
       xlabel='x',
       ylabel='y',
       zlabel='z')

plt.show()

# %% [markdown]
# ### **3D Scatter Plot**

# %%
z = np.linspace(0, 1, 100)
x = z * np.sin(20 * z)
z = z * np.cos(20 * z)

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.scatter(x, y, z, color='g')

ax.set(title='Contoh 3D Scatter Plot',
       xlabel='Sumbu X',
       ylabel='Sumbu Y',
       zlabel='Sumbu Z')

plt.show()
