# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/matplotlib-with-indonesia-belajar/blob/main/Matplotlib_21_%7C_Pandas_Data_Frame_dan_Matplotlib_%7C_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Matplotlib 21 | Pandas Data Frame dan Matplotlib | Part 2 | Belajar Visualisasi Data**

# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

print(matplotlib.__version__)
print(pd.__version__)
# Out:
# 3.10.0
# 2.2.2

# %% [markdown]
# ### **Line Plot**
#
# Sample Dataset

# %%
data = {
    'Tahun': [
        '1958', '1963', '1968', '1973', '1978', '1983', '1988', '1993', '1998', '2003', '2008', '2013', '2018'],
    'Populasi': [51652500, 53624900, 55213500, 56223000, 56178000, 56315000, 56916000, 57713000, 58474000, 59636000, 61823000, 64105000, 66436000]
}

df = pd.DataFrame(data)
df
# Out:
#    Tahun  Populasi
# 0   1958  51652500
# 1   1963  53624900
# 2   1968  55213500
# 3   1973  56223000
# 4   1978  56178000
# 5   1983  56315000
# 6   1988  56916000
# 7   1993  57713000
# 8   1998  58474000
# 9   2003  59636000
# 10  2008  61823000
# 11  2013  64105000
# 12  2018  66436000

# %%
df.plot(x='Tahun', y='Populasi', kind='line')

plt.title('Data Populasi Penduduk Indonesia')
plt.ylabel('Populasi (dalam Juta Orang)')
plt.xlabel('Tahun')
plt.show()

# %% [markdown]
# ### **Bar Plot**
#
# Sample Dataset

# %%
data = {
    'Negara': ['United States', 'Singapore', 'Germany', 'United Kingdom', 'Japan'],
    'GDP': [62606, 100345, 52559, 45705, 44227]
}

df = pd.DataFrame(data, columns=['Negara', 'GDP'])
df
# Out:
#            Negara     GDP
# 0   United States   62606
# 1       Singapore  100345
# 2         Germany   52559
# 3  United Kingdom   45705
# 4           Japan   44227

# %%
df.plot(x='Negara', y='GDP', kind='bar')

plt.title('GDP Per Kapita')
plt.ylabel('GDP ($)')
plt.xlabel('Negara')
plt.show()

# %%
df.plot(x='Negara', y='GDP', kind='barh')

plt.title('GDP Per Kapita')
plt.ylabel('Negara')
plt.xlabel('GDP ($)')
plt.show()

# %%
df.plot(x='Negara', y='GDP', kind='barh', color='g', legend=False)

plt.title('GDP Per Kapita')
plt.ylabel('Negara')
plt.xlabel('GDP ($)')
plt.show()

# %% [markdown]
# ### **Scatter Plot**
#
# Sample Dataset

# %%
data = {
    'Negara': ['United States', 'Singapore', 'Germany', 'United Kingdom', 'Japan'],
    'GDP': [62606, 100345, 52559, 45705, 44227],
    'Life_Expetancy': [79.24, 82.84, 80.84, 81.40, 83.64]
}

df = pd.DataFrame(data, columns=['Negara', 'GDP', 'Life_Expetancy'])
df
# Out:
#            Negara     GDP  Life_Expetancy
# 0   United States   62606           79.24
# 1       Singapore  100345           82.84
# 2         Germany   52559           80.84
# 3  United Kingdom   45705           81.40
# 4           Japan   44227           83.64

# %%
df.plot(kind='scatter', x='GDP', y='Life_Expetancy', color='r',
        title='GDP and Life Expetancy', ylabel='Life Expetancy', xlabel='GDP')

plt.show()

# %% [markdown]
# ### **Pie Plot**
#
# Sample Dataset

# %%
data = {
    'Benua': ['Asia', 'Afrika', 'Eropa', 'Amerika Utara', 'Amerika Selatan', 'Australia', 'Antartika'],
    'Populasi': [4641054775, 1340598147, 747636026, 592072212, 430759766, 40269482, 1000]
}

df = pd.DataFrame(data)
df
# Out:
#              Benua    Populasi
# 0             Asia  4641054775
# 1           Afrika  1340598147
# 2            Eropa   747636026
# 3    Amerika Utara   592072212
# 4  Amerika Selatan   430759766
# 5        Australia    40269482
# 6        Antartika        1000

# %%
df.plot(kind='pie', y='Populasi', x='Benua', figsize=(6, 6),
        title='Populasi di tiap benua')

plt.show()

# %%
df.plot(kind='pie', y='Populasi', x='Benua',
        title='Populasi di tiap benua')

plt.show()

# %%
df = df.set_index('Benua')
df
# Out:
#                    Populasi
# Benua
# Asia             4641054775
# Afrika           1340598147
# Eropa             747636026
# Amerika Utara     592072212
# Amerika Selatan   430759766
# Australia          40269482
# Antartika              1000

# %%
df.plot(kind='pie', y='Populasi', x='Benua', figsize=(6, 6),
        title='Populasi di tiap benua')

plt.show()
