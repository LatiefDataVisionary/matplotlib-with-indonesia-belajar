# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/matplotlib-with-indonesia-belajar/blob/main/Matplotlib_14_Belajar_Contour_Plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Matplotlib 14: Belajar Contour Plot | Contour Chart | Belajar Matplotlib Dasar | Visualisasi Data**

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

print(matplotlib.__version__)
print(np.__version__)
# Out:
# 3.10.0
# 1.26.4

# %% [markdown]
# ### **Sample Dataset**

# %%
n = np.linspace(-3.0, 3.0, 100)

x, y = np.meshgrid(n, n)
z = np.sqrt(x**2 + y**2)

print(x.shape)
print(y.shape)
print(z.shape)
# Out:
# (100, 100)
# (100, 100)
# (100, 100)

# %%
x
# Out:
# array([[-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        ...,
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ],
#        [-3.        , -2.93939394, -2.87878788, ...,  2.87878788,
#          2.93939394,  3.        ]])

# %%
y
# Out:
# array([[-3.        , -3.        , -3.        , ..., -3.        ,
#         -3.        , -3.        ],
#        [-2.93939394, -2.93939394, -2.93939394, ..., -2.93939394,
#         -2.93939394, -2.93939394],
#        [-2.87878788, -2.87878788, -2.87878788, ..., -2.87878788,
#         -2.87878788, -2.87878788],
#        ...,
#        [ 2.87878788,  2.87878788,  2.87878788, ...,  2.87878788,
#          2.87878788,  2.87878788],
#        [ 2.93939394,  2.93939394,  2.93939394, ...,  2.93939394,
#          2.93939394,  2.93939394],
#        [ 3.        ,  3.        ,  3.        , ...,  3.        ,
#          3.        ,  3.        ]])

# %%
z
# Out:
# array([[4.24264069, 4.20000437, 4.15781429, ..., 4.15781429, 4.20000437,
#         4.24264069],
#        [4.20000437, 4.15693077, 4.11429901, ..., 4.11429901, 4.15693077,
#         4.20000437],
#        [4.15781429, 4.11429901, 4.07122086, ..., 4.07122086, 4.11429901,
#         4.15781429],
#        ...,
#        [4.15781429, 4.11429901, 4.07122086, ..., 4.07122086, 4.11429901,
#         4.15781429],
#        [4.20000437, 4.15693077, 4.11429901, ..., 4.11429901, 4.15693077,
#         4.20000437],
#        [4.24264069, 4.20000437, 4.15781429, ..., 4.15781429, 4.20000437,
#         4.24264069]])

# %% [markdown]
# ### **Contour Plot**

# %%
plt.contourf(x, y, z)
plt.colorbar()

plt.title('Countour Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()

# %% [markdown]
# ### **Filled Contour Plot**

# %%
plt.contour(x, y, z)
plt.colorbar()

plt.title('Filled Countour Plot')
plt.xlabel('Sumbu X')
plt.ylabel('Sumbu Y')

plt.show()
